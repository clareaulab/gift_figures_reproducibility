# %% [markdown]
# # Example cell cycle assignment

# %%
import scanpy as sc
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy 

import sys
sys.path.append('../../1_figure_CL_proof_of_concept/code/')
import utils_00 as gf_utils
large_data_dir = gf_utils.large_data_dir

# %%
adata_dir = large_data_dir + 'MPN_WTA/MPN_1_BC002_genotyped.h5ad'
adata = sc.read_h5ad(adata_dir)

### from https://github.com/scverse/scanpy_usage/blob/master/180209_cell_cycle/cell_cycle.ipynb
cell_cycle_genes = [x.strip() for x in open('../data/regev_lab_cell_cycle_genes.txt')]
print(len(cell_cycle_genes))
s_genes = cell_cycle_genes[:43]
g2m_genes = cell_cycle_genes[43:]
cell_cycle_genes = [x for x in cell_cycle_genes if x in adata.var_names]
print(len(cell_cycle_genes))

adata.X = adata.layers['zs_norm_log'].copy()

sc.tl.score_genes_cell_cycle(adata, s_genes=s_genes, g2m_genes=g2m_genes)
df = adata.obs[['S_score','G2M_score','phase']].copy()
# Out:
# 97
# 89
# WARNING: genes are not in var_names and ignored: Index(['MLF1IP', 'E2F8'], dtype='object')
# WARNING: genes are not in var_names and ignored: Index(['BIRC5', 'FAM64A', 'HN1', 'CDC25C', 'CDCA2', 'NEK2'], dtype='object')

# %%
### run for all patients and concatenated df saved as ../data/MPN_patients_cell_cycle_scores.csv
